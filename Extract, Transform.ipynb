# %%
import pandas as pd

# %%
raw_data_csv = pd.read_csv("fd-export.csv", low_memory=False)

# %%
raw_data_csv.head()
# Out:
#                             user_id   age     sex country checkin_date  \
# 0  QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN     NaN     NaN   2015-11-26
# 1  QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  31.0    male      US   2015-11-26
# 2  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 3  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 4  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
#
#   trackable_id trackable_type  \
# 0         1069      Condition
# 1         1069      Condition
# 2         3168      Condition
# 3         3169      Condition
# 4         3170      Condition
#
#                                       trackable_name trackable_value
# 0                                 Ulcerative colitis               0
# 1                                 Ulcerative colitis               0
# 2  pain in left upper arm felt like i was getting...               4
# 3                            hip pain when gettin up               3
# 4                                pain in hand joints               4

# %%
raw_data_csv.size
# Out:
# 31388697

# %%
data_pd = raw_data_csv[["age","sex","country","checkin_date","trackable_type","trackable_name"]]

# %%
data_pd=data_pd.dropna(how="any")

# %%
data_pd=data_pd[data_pd["trackable_type"]=="Condition"]

# %%
data_pd
# Out:
#           age     sex country checkin_date trackable_type  \
# 1        31.0    male      US   2015-11-26      Condition
# 2         1.0  female      CA   2017-04-28      Condition
# 3         1.0  female      CA   2017-04-28      Condition
# 4         1.0  female      CA   2017-04-28      Condition
# 5         1.0  female      CA   2017-04-28      Condition
# 6         1.0  female      CA   2017-04-28      Condition
# 7         1.0  female      CA   2017-04-28      Condition
# 8         1.0  female      CA   2017-04-28      Condition
# 9         1.0  female      CA   2017-04-28      Condition
# 10        1.0  female      CA   2017-04-28      Condition
# 11        1.0  female      CA   2017-04-28      Condition
# 12        1.0  female      CA   2017-04-28      Condition
# 13        1.0  female      CA   2017-04-28      Condition
# 14        1.0  female      CA   2017-04-28      Condition
# 65       30.0  female      US   2015-07-17      Condition
# 66       30.0  female      US   2015-07-17      Condition
# 67       30.0  female      US   2015-07-17      Condition
# 68       30.0  female      US   2015-07-17      Condition
# 69       30.0  female      US   2015-07-17      Condition
# 70       30.0  female      US   2015-07-17      Condition
# 87       30.0  female      US   2015-08-10      Condition
# 88       30.0  female      US   2015-08-10      Condition
# 89       30.0  female      US   2015-08-10      Condition
# 90       30.0  female      US   2015-08-10      Condition
# 91       30.0  female      US   2015-08-10      Condition
# 92       30.0  female      US   2015-08-10      Condition
# 103      30.0  female      US   2015-07-26      Condition
# 104      30.0  female      US   2015-07-26      Condition
# 105      30.0  female      US   2015-07-26      Condition
# 106      30.0  female      US   2015-07-26      Condition
# ...       ...     ...     ...          ...            ...
# 3487258  44.0  female      US   2018-07-07      Condition
# 3487259  44.0  female      US   2018-07-07      Condition
# 3487260  44.0  female      US   2018-07-07      Condition
# 3487261  44.0  female      US   2018-07-07      Condition
# 3487281  44.0  female      US   2018-07-09      Condition
# 3487282  44.0  female      US   2018-07-09      Condition
# 3487283  44.0  female      US   2018-07-09      Condition
# 3487284  44.0  female      US   2018-07-09      Condition
# 3487285  44.0  female      US   2018-07-09      Condition
# 3487306  44.0  female      US   2018-07-11      Condition
# 3487307  44.0  female      US   2018-07-11      Condition
# 3487308  44.0  female      US   2018-07-11      Condition
# 3487309  44.0  female      US   2018-07-11      Condition
# 3487310  44.0  female      US   2018-07-11      Condition
# 3487311  44.0  female      US   2018-07-11      Condition
# 3487407  27.0  female      AU   2018-07-13      Condition
# 3487445  17.0  female      FR   2017-12-11      Condition
# 3487446  17.0  female      FR   2017-12-11      Condition
# 3487462  17.0  female      FR   2018-07-10      Condition
# 3487485  17.0  female      FR   2018-07-11      Condition
# 3487486  17.0  female      FR   2018-07-11      Condition
# 3487487  17.0  female      FR   2018-07-11      Condition
# 3487519  17.0  female      FR   2018-07-12      Condition
# 3487520  17.0  female      FR   2018-07-12      Condition
# 3487521  17.0  female      FR   2018-07-12      Condition
# 3487522  17.0  female      FR   2018-07-12      Condition
# 3487558  34.0  female      CA   2018-07-12      Condition
# 3487559  34.0  female      CA   2018-07-12      Condition
# 3487593  24.0    male      GB   2018-07-12      Condition
# 3487594  24.0    male      GB   2018-07-12      Condition
#
#                                             trackable_name
# 1                                       Ulcerative colitis
# 2        pain in left upper arm felt like i was getting...
# 3                                  hip pain when gettin up
# 4                                      pain in hand joints
# 5                                   numbness in right hand
# 6                                                 Headache
# 7                                       pain in left ankle
# 8                                         pain in left leg
# 9                                   pain in joints on feet
# 10                                neck and upper back pain
# 11                              neck pain at base of scull
# 12                        pain inside arm and around elbow
# 13                                                diziness
# 14                                    pain in face and jaw
# 65                           Obsessive-compulsive disorder
# 66                                           Ovarian cysts
# 67                                         Sinus headaches
# 68                                   Temporal lobe seizure
# 69                                         Bipolar type II
# 70                                   Oral Allergy Syndrome
# 87                           Obsessive-compulsive disorder
# 88                                           Ovarian cysts
# 89                                         Sinus headaches
# 90                                   Temporal lobe seizure
# 91                                         Bipolar type II
# 92                                   Oral Allergy Syndrome
# 103                          Obsessive-compulsive disorder
# 104                                          Ovarian cysts
# 105                                        Sinus headaches
# 106                                  Temporal lobe seizure
# ...                                                    ...
# 3487258                             Traumatic brain injury
# 3487259                                  Chronic Migraines
# 3487260                                       Fibromyalgia
# 3487261                                             ME/CFS
# 3487281                                           Epilepsy
# 3487282                             Traumatic brain injury
# 3487283                                  Chronic Migraines
# 3487284                                       Fibromyalgia
# 3487285                                             ME/CFS
# 3487306                                           Epilepsy
# 3487307                             Traumatic brain injury
# 3487308                                  Chronic Migraines
# 3487309                                       Fibromyalgia
# 3487310                                             ME/CFS
# 3487311                          Chronic hives (urticaria)
# 3487407                                               ADHD
# 3487445                               Small vessel disease
# 3487446                                        mood swings
# 3487462                               chronic lyme disease
# 3487485                               chronic lyme disease
# 3487486                                        mood swings
# 3487487                                             Period
# 3487519                                             Period
# 3487520                               chronic lyme disease
# 3487521                                        mood swings
# 3487522                                       dissociation
# 3487558                                           Reynauds
# 3487559         Undifferentiated Connective Tissue Disease
# 3487593                              Indeterminate Colitis
# 3487594                   Inflammatory bowel disease (IBD)
#
# [471958 rows x 6 columns]

# %%
# Out:
# array([ 3.1000e+01,  1.0000e+00,  3.0000e+01,  2.8000e+01,  2.9000e+01,
#         3.6000e+01,  2.3000e+01,  4.1000e+01,  4.4000e+01,  4.0000e+01,
#         3.3000e+01,  4.6000e+01,  3.2000e+01,  2.4000e+01,  1.1700e+02,
#         4.5000e+01,  5.0000e+01,  3.7000e+01,  4.3000e+01,  6.1000e+01,
#         2.7000e+01,  1.9000e+01,  7.5000e+01,  4.8000e+01,  5.2000e+01,
#         5.4000e+01,  2.1000e+01,  4.2000e+01,  1.8000e+01,  6.2000e+01,
#         2.2000e+01,  3.5000e+01,  5.3000e+01,  3.4000e+01,  6.3000e+01,
#         2.5000e+01,  2.6000e+01,  3.8000e+01,  5.5000e+01,  6.4000e+01,
#         5.9000e+01,  5.6000e+01,  0.0000e+00,  5.8000e+01,  8.8000e+01,
#         6.0000e+01,  5.7000e+01,  6.8000e+01,  3.9000e+01,  5.1000e+01,
#         7.3000e+01,  1.5000e+01,  4.7000e+01,  7.0000e+01,  2.0000e+00,
#         1.7000e+01,  6.7000e+01,  7.7000e+01,  2.0000e+01,  4.9000e+01,
#        -4.5000e+01,  6.5000e+01,  7.1000e+01,  7.4000e+01,  8.0000e+00,
#         5.0000e+00,  1.4000e+01,  6.6000e+01,  4.0000e+00, -1.9964e+04,
#         1.6000e+01,  9.0000e+00,  6.9000e+01,  7.0000e+00,  3.0000e+00,
#         1.9410e+03,  1.2000e+01,  6.0000e+00,  1.3000e+01,  1.1000e+01,
#         7.9000e+01, -3.4000e+01,  1.0000e+01,  8.9000e+01,  2.0170e+03,
#         2.1800e+02,  8.2800e+02, -1.0000e+00,  3.5900e+02,  7.2000e+01,
#         8.3000e+01,  9.8000e+01])
